# %% [markdown]
# ## Using PV-MCTS method with "perfect" copy of the environment in the stochastic setting
#
# If implemented properly (still to be checked), the most probable mode of failure is the one of planning in hindsight of the wrong event: basically you sample a transition and treat it as if it's the only possible transition and find the best action in this new determinization of the environment (which is similar to re-planning in hindsight if the transition actually happened). The problem with this is that you are planning while taking for sure an event that might not happen and you do not take into account any other possibility nor any uncertainty.
#
# TODO:
# - load stochastic environment - ok
# - re-use code from notebook 9 to show that the simulated transitions can be different from those of that are actually realized in the environment - ok
# - run the script run_PVMCTS_v2 with plausible parameters for a baseline and the option --game_name groups_simple

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import time
import copy
# custom imports
import utils
import train
import mcts
from rtfm import featurizer as X
import os
from torch import multiprocessing as mp
import random
# Out:
# Using device cuda:0
# Using device cuda:0

# %%
# Check only if main logic of the training loop works
ucb_C = 1.0
discount = 0.9 # try with smaller discount
episode_length = 32
max_actions = 20
num_simulations = 10
num_trees = 3
#device = mcts.device
n_episodes = 4000
memory_size = 1024
batch_size = 32
n_steps = 5
tau = 0.1 # new_trg_params = (1-tau)*old_trg_params + tau*value_net_params
dir_noise = False
dirichlet_alpha = 0.5 # no real reason to choose this value, except it's < 1
exploration_fraction = 0.25
temperature = 1.
full_cross_entropy = True
entropy_bonus = True
entropy_weight = 1e-2

# %%
flags = utils.Flags(env="rtfm:groups_simple-v0")
gym_env = utils.create_env(flags)
featurizer = X.Render()
env = mcts.FullTrueSimulator(gym_env, featurizer)
object_ids = utils.get_object_ids_dict(env)
pv_net = mcts.DiscreteSupportPVNet_v3(gym_env)

# %%
# run little MCTS in debug mode, look at the transition for a particular action 
# and then look at the same transition if the action is played in the real env

# %%
random.seed(1) 
frame, valid_actions = env.reset()
env.render() # this should be fixed even if the notebook is restarted
# Out:
# ██████
# █ @!n█
# █    █
# █    █
# █?  y█
# ██████

# %%
def run_mcts_step(debug_render=True):
    tree = mcts.PV_MCTS(
                         frame, 
                         env, 
                         valid_actions, 
                         ucb_C, 
                         discount, 
                         max_actions, 
                         pv_net,
                         render=debug_render, 
                         ucb_method='p-UCT-AlphaGo'
                         )
    
    root, info = tree.run(num_simulations, 
                          mode='predict', 
                          dir_noise=dir_noise, 
                          dirichlet_alpha=dirichlet_alpha, 
                          exploration_fraction=exploration_fraction
                         )
    
    return tree, root

# %%
tree, root = run_mcts_step()
# Out:
# Valid actions as child:  [0 2 3 4]
# Prior over the children:  [0.16766171 0.         0.24954093 0.31134227 0.27145508]
# Weights over the children:  [0.2059684  0.         0.25127804 0.28067434 0.26207924]
# Terminal node:  False
#
# Simulation 1 started.
#
# ██████
# █ @!n█
# █    █
# █    █
# █?  y█
# ██████
#
# actions:  [0 2 3 4]
# value_terms:  [0 0 0 0]
# exploration_terms:  [0.16766171 0.24954093 0.31134227 0.27145508]
# ucb_values:  [0.16766171 0.24954093 0.31134227 0.27145508]
# max_U:  0.3113422691822052
# mask:  [False False  True False]
# best_actions:  [3]
# Current tree depth:  1
# Action selected:  3 Left
# Child node terminal:  False
# Child node expanded:  False
# Expansion phase started
# valid_actions:  [0 2 4]
# prior:  [0.23154376 0.         0.36660463 0.         0.40185165]
# reward:  0
# done:  False
# Valid actions as child:  [0 2 4]
# Prior over the children:  [0.23154376 0.         0.36660463 0.         0.40185165]
# Weights over the children:  [0.27966624 0.         0.3519026  0.         0.36843118]
# Terminal node:  False
#
# ██████
# █@ !n█
# █    █
# █    █
# █ ? y█
# ██████
#
# Value prediction/simulation phase started
# Predicted/simulated value:  -0.00609199982136488
# Backpropagation phase started
# Simulation 1 done.
#
# Simulation 2 started.
#
# ██████
# █ @!n█
# █    █
# █    █
# █?  y█
# ██████
#
# actions:  [0 2 3 4]
# value_terms:  [ 0.         0.        -0.0054828  0.       ]
# exploration_terms:  [0.23710947 0.35290416 0.22015223 0.38389545]
# ucb_values:  [0.23710947 0.35290416 0.21466943 0.38389545]
# max_U:  0.38389545474529707
# mask:  [False False False  True]
# best_actions:  [4]
# Current tree depth:  1
# Action selected:  4 Right
# Child node terminal:  False
# Child node expanded:  False
# Expansion phase started
# valid_actions:  [0 1 2 3 4]
# prior:  [0.13098091 0.1601776  0.20472412 0.27053136 0.23358609]
# reward:  -1
# done:  True
# Valid actions as child:  [0 1 2 3 4]
# Prior over the children:  [0.13098091 0.1601776  0.20472412 0.27053136 0.23358609]
# Weights over the children:  [0.16316839 0.18044004 0.20399359 0.2344989  0.21789914]
# Terminal node:  True
#
# ██████
# █   n█
# █  ! █
# █?   █
# █   y█
# ██████
#
# Value prediction/simulation phase started
# Predicted/simulated value:  0
# Backpropagation phase started
# Simulation 2 done.
#
# Simulation 3 started.
#
# ██████
# █ @!n█
# █    █
# █    █
# █?  y█
# ██████
#
# actions:  [0 2 3 4]
# value_terms:  [ 0.         0.        -0.0054828 -1.       ]
# exploration_terms:  [0.2903986  0.43221756 0.26963031 0.23508699]
# ucb_values:  [ 0.2903986   0.43221756  0.26414751 -0.76491301]
# max_U:  0.43221756071266393
# mask:  [False  True False False]
# best_actions:  [2]
# Current tree depth:  1
# Action selected:  2 Down
# Child node terminal:  False
# Child node expanded:  False
# Expansion phase started
# valid_actions:  [0 1 2 3 4]
# prior:  [0.13682233 0.1543738  0.2198349  0.26666692 0.22230206]
# reward:  0
# done:  False
# Valid actions as child:  [0 1 2 3 4]
# Prior over the children:  [0.13682233 0.1543738  0.2198349  0.26666692 0.22230206]
# Weights over the children:  [0.166653   0.17701964 0.21124332 0.23265867 0.21242538]
# Terminal node:  False
#
# ██████
# █ ! n█
# █ @  █
# █    █
# █ ? y█
# ██████
#
# Value prediction/simulation phase started
# Predicted/simulated value:  -0.007004770450294018
# Backpropagation phase started
# Simulation 3 done.
#
# Simulation 4 started.
#
# ██████
# █ @!n█
# █    █
# █    █
# █?  y█
# ██████
#
# actions:  [0 2 3 4]
# value_terms:  [ 0.         -0.00630429 -0.0054828  -1.        ]
# exploration_terms:  [0.33532342 0.24954093 0.31134227 0.27145508]
# ucb_values:  [ 0.33532342  0.24323663  0.30585947 -0.72854492]
# max_U:  0.33532342314720154
# mask:  [ True False False False]
# best_actions:  [0]
# Current tree depth:  1
# Action selected:  0 Stay
# Child node terminal:  False
# Child node expanded:  False
# Expansion phase started
# valid_actions:  [0 1 2 3 4]
# prior:  [0.14409113 0.15254863 0.20576882 0.26421937 0.23337212]
# reward:  -1
# done:  True
# Valid actions as child:  [0 1 2 3 4]
# Prior over the children:  [0.14409113 0.15254863 0.20576882 0.26421937 0.23337212]
# Weights over the children:  [0.17091915 0.17586371 0.20424992 0.23144852 0.2175187 ]
# Terminal node:  True
#
# ██████
# █ ! n█
# █    █
# █    █
# █?  y█
# ██████
#
# Value prediction/simulation phase started
# Predicted/simulated value:  0
# Backpropagation phase started
# Simulation 4 done.
#
# Simulation 5 started.
#
# ██████
# █ @!n█
# █    █
# █    █
# █?  y█
# ██████
#
# actions:  [0 2 3 4]
# value_terms:  [-1.         -0.00630429 -0.0054828  -1.        ]
# exploration_terms:  [0.18745149 0.27899524 0.34809124 0.30349601]
# ucb_values:  [-0.81254851  0.27269094  0.34260844 -0.69650399]
# max_U:  0.342608439240996
# mask:  [False False  True False]
# best_actions:  [3]
#
# ██████
# █@ !n█
# █    █
# █    █
# █ ? y█
# ██████
#
# Current tree depth:  1
# Action selected:  3 Left
# Child node terminal:  False
# Child node expanded:  True
# actions:  [0 2 4]
# value_terms:  [0 0 0]
# exploration_terms:  [0.23154376 0.36660463 0.40185165]
# ucb_values:  [0.23154376 0.36660463 0.40185165]
# max_U:  0.4018516540527344
# mask:  [False False  True]
# best_actions:  [4]
# Current tree depth:  2
# Action selected:  4 Right
# Child node terminal:  False
# Child node expanded:  False
# Expansion phase started
# valid_actions:  [0 1 2 3 4]
# prior:  [0.13812627 0.15064272 0.21230882 0.27254072 0.22638147]
# reward:  -1
# done:  True
# Valid actions as child:  [0 1 2 3 4]
# Prior over the children:  [0.13812627 0.15064272 0.21230882 0.27254072 0.22638147]
# Weights over the children:  [0.16753216 0.17495814 0.20770362 0.23532915 0.21447688]
# Terminal node:  True
#
# ██████
# █ ! n█
# █    █
# █ ?  █
# █   y█
# ██████
#
# Value prediction/simulation phase started
# Predicted/simulated value:  0
# Backpropagation phase started
# Simulation 5 done.
#
# Simulation 6 started.
#
# ██████
# █ @!n█
# █    █
# █    █
# █?  y█
# ██████
#
# actions:  [0 2 3 4]
# value_terms:  [-1.         -0.00630429 -0.4527414  -1.        ]
# exploration_terms:  [0.20534282 0.30562397 0.2542099  0.33246322]
# ucb_values:  [-0.79465718  0.29931967 -0.1985315  -0.66753678]
# max_U:  0.2993196747225683
# mask:  [False  True False False]
# best_actions:  [2]
#
# ██████
# █ ! n█
# █ @  █
# █    █
# █ ? y█
# ██████
#
# Current tree depth:  1
# Action selected:  2 Down
# Child node terminal:  False
# Child node expanded:  True
# actions:  [0 1 2 3 4]
# value_terms:  [0 0 0 0 0]
# exploration_terms:  [0.13682233 0.15437379 0.21983489 0.26666692 0.22230206]
# ucb_values:  [0.13682233 0.15437379 0.21983489 0.26666692 0.22230206]
# max_U:  0.2666669189929962
# mask:  [False False False  True False]
# best_actions:  [3]
# Current tree depth:  2
# Action selected:  3 Left
# Child node terminal:  False
# Child node expanded:  False
# Expansion phase started
# valid_actions:  [0 1 2 4]
# prior:  [0.18383569 0.19508089 0.29586983 0.         0.3252136 ]
# reward:  0
# done:  False
# Valid actions as child:  [0 1 2 4]
# Prior over the children:  [0.18383569 0.19508089 0.29586983 0.         0.3252136 ]
# Weights over the children:  [0.21603794 0.22254737 0.2740725  0.         0.28734222]
# Terminal node:  False
#
# ██████
# █   n█
# █@!  █
# █ ?  █
# █   y█
# ██████
#
# Value prediction/simulation phase started
# Predicted/simulated value:  -0.00046059489250183105
# Backpropagation phase started
# Simulation 6 done.
#
# Simulation 7 started.
#
# ██████
# █ @!n█
# █    █
# █    █
# █?  y█
# ██████
#
# actions:  [0 2 3 4]
# value_terms:  [-1.         -0.00333869 -0.4527414  -1.        ]
# exploration_terms:  [0.2217956  0.22007441 0.27457807 0.35910132]
# ucb_values:  [-0.7782044   0.21673572 -0.17816333 -0.64089868]
# max_U:  0.21673572221645487
# mask:  [False  True False False]
# best_actions:  [2]
#
# ██████
# █ ! n█
# █ @  █
# █    █
# █ ? y█
# ██████
#
# Current tree depth:  1
# Action selected:  2 Down
# Child node terminal:  False
# Child node expanded:  True
# actions:  [0 1 2 3 4]
# value_terms:  [ 0.          0.          0.         -0.00041454  0.        ]
# exploration_terms:  [0.19349599 0.21831751 0.31089349 0.18856199 0.31438259]
# ucb_values:  [0.19349599 0.21831751 0.31089349 0.18814745 0.31438259]
# max_U:  0.31438259427600673
# mask:  [False False False False  True]
# best_actions:  [4]
# Current tree depth:  2
# Action selected:  4 Right
# Child node terminal:  False
# Child node expanded:  False
# Expansion phase started
# valid_actions:  [0 1 2 3 4]
# prior:  [0.13733135 0.1552029  0.21709473 0.26291698 0.22745411]
# reward:  0
# done:  False
# Valid actions as child:  [0 1 2 3 4]
# Prior over the children:  [0.13733135 0.1552029  0.21709473 0.26291698 0.22745411]
# Weights over the children:  [0.16691773 0.17744651 0.20986606 0.23095477 0.21481495]
# Terminal node:  False
#
# ██████
# █   n█
# █ !@ █
# █ ?  █
# █   y█
# ██████
#
# Value prediction/simulation phase started
# Predicted/simulated value:  -0.012726282700896263
# Backpropagation phase started
# Simulation 7 done.
#
# Simulation 8 started.
#
# ██████
# █ @!n█
# █    █
# █    █
# █?  y█
# ██████
#
# actions:  [0 2 3 4]
# value_terms:  [-1.         -0.00566189 -0.4527414  -1.        ]
# exploration_terms:  [0.23710947 0.17645208 0.29353631 0.38389545]
# ucb_values:  [-0.76289053  0.17079019 -0.15920509 -0.61610455]
# max_U:  0.1707901921841003
# mask:  [False  True False False]
# best_actions:  [2]
#
# ██████
# █ ! n█
# █ @  █
# █    █
# █ ? y█
# ██████
#
# Current tree depth:  1
# Action selected:  2 Down
# Child node terminal:  False
# Child node expanded:  True
# actions:  [0 1 2 3 4]
# value_terms:  [ 0.          0.          0.         -0.00041454 -0.01145365]
# exploration_terms:  [0.23698322 0.26738326 0.38076521 0.23094033 0.19251923]
# ucb_values:  [0.23698322 0.26738326 0.38076521 0.23052579 0.18106558]
# max_U:  0.38076520558385046
# mask:  [False False  True False False]
# best_actions:  [2]
# Current tree depth:  2
# Action selected:  2 Down
# Child node terminal:  False
# Child node expanded:  False
# Expansion phase started
# valid_actions:  [0 1 2 3 4]
# prior:  [0.13641916 0.15356545 0.2195319  0.26148498 0.22899845]
# reward:  -1
# done:  True
# Valid actions as child:  [0 1 2 3 4]
# Prior over the children:  [0.13641916 0.15356545 0.2195319  0.26148498 0.22899845]
# Weights over the children:  [0.1663992  0.17654698 0.21108742 0.23037581 0.2155906 ]
# Terminal node:  True
#
# ██████
# █   n█
# █ !  █
# █ ?  █
# █   y█
# ██████
#
# Value prediction/simulation phase started
# Predicted/simulated value:  0
# Backpropagation phase started
# Simulation 8 done.
#
# Simulation 9 started.
#
# ██████
# █ @!n█
# █    █
# █    █
# █?  y█
# ██████
# actions:  [0 2 3 4]
# value_terms:  [-1.         -0.22924642 -0.4527414  -1.        ]
# exploration_terms:  [0.25149257 0.14972456 0.31134227 0.40718262]
# ucb_values:  [-0.74850743 -0.07952186 -0.14139913 -0.59281738]
# max_U:  -0.0795218610484153
# mask:  [False  True False False]
# best_actions:  [2]
#
# ██████
# █ ! n█
# █ @  █
# █    █
# █ ? y█
# ██████
#
# Current tree depth:  1
# Action selected:  2 Down
# Child node terminal:  False
# Child node expanded:  True
# actions:  [0 1 2 3 4]
# value_terms:  [ 0.00000000e+00  0.00000000e+00 -1.00000000e+00 -4.14535403e-04
#  -1.14536544e-02]
# exploration_terms:  [0.27364466 0.30874759 0.21983489 0.26666692 0.22230206]
# ucb_values:  [ 0.27364466  0.30874759 -0.78016511  0.26625238  0.21084841]
# max_U:  0.3087475895881653
# mask:  [False  True False False False]
# best_actions:  [1]
# Current tree depth:  2
# Action selected:  1 Up
# Child node terminal:  False
# Child node expanded:  False
# Expansion phase started
# valid_actions:  [0 1 2 3 4]
# prior:  [0.13641916 0.15356545 0.2195319  0.26148498 0.22899845]
# reward:  -1
# done:  True
# Valid actions as child:  [0 1 2 3 4]
# Prior over the children:  [0.13641916 0.15356545 0.2195319  0.26148498 0.22899845]
# Weights over the children:  [0.1663992  0.17654698 0.21108742 0.23037581 0.2155906 ]
# Terminal node:  True
#
# ██████
# █   n█
# █ !  █
# █ ?  █
# █   y█
# ██████
#
# Value prediction/simulation phase started
# Predicted/simulated value:  0
# Backpropagation phase started
# Simulation 9 done.
#
# Simulation 10 started.
#
# ██████
# █ @!n█
# █    █
# █    █
# █?  y█
# ██████
#
# actions:  [0 2 3 4]
# value_terms:  [-1.         -0.36339713 -0.4527414  -1.        ]
# exploration_terms:  [0.26509644 0.13151962 0.32818357 0.42920817]
# ucb_values:  [-0.73490356 -0.23187752 -0.12455783 -0.57079183]
# max_U:  -0.12455783241927498
# mask:  [False False  True False]
# best_actions:  [3]
#
# ██████
# █@ !n█
# █    █
# █    █
# █ ? y█
# ██████
#
# Current tree depth:  1
# Action selected:  3 Left
# Child node terminal:  False
# Child node expanded:  True
# actions:  [0 2 4]
# value_terms:  [ 0.  0. -1.]
# exploration_terms:  [0.32745233 0.51845723 0.28415203]
# ucb_values:  [ 0.32745233  0.51845723 -0.71584797]
# max_U:  0.5184572343706948
# mask:  [False  True False]
# best_actions:  [2]
# Current tree depth:  2
# Action selected:  2 Down
# Child node terminal:  False
# Child node expanded:  False
# Expansion phase started
# valid_actions:  [0 1 2 4]
# prior:  [0.19433068 0.1989237  0.298718   0.         0.3080276 ]
# reward:  0
# done:  False
# Valid actions as child:  [0 1 2 4]
# Prior over the children:  [0.19433068 0.1989237  0.298718   0.         0.3080276 ]
# Weights over the children:  [0.22170158 0.22430626 0.2748709  0.         0.27912125]
# Terminal node:  False
#
# ██████
# █ ! n█
# █@   █
# █    █
# █ ? y█
# ██████
#
# Value prediction/simulation phase started
# Predicted/simulated value:  -0.0030927807092666626
# Backpropagation phase started
# Simulation 10 done.

# %%
# let's look at the left action's (3) transition
env.step(3)
env.render() # this trasition is clearly different from the one used in the internal simulation of the MCTS
# Out:
# ██████
# █@! n█
# █    █
# █    █
# █ ? y█
# ██████
